# %% [markdown]
# #1. Hello, Python

# %% [markdown]
# #### Variable assignment
# Here we create a variable called `spam_amount` and assign it the value of 0 using `=`, which is called the assignment operator.

# %%
spam_amount = 0

# %% [markdown]
# #### Function calls:
# `print` is a Python function that displays the value passed to it on the screen. We call functions by putting parentheses after their name, and putting the inputs (or arguments) to the function in those parentheses.

# %%
print(spam_amount)
# Out:
# 0

# %% [markdown]
# #### Reassignment
# Reassigning the value of an existing variable looks just the same as creating a variable. It still uses the `=` assignment operator.
# > In this case, Python evaluates the expression on the right-hand-side of the `=` (0 + 4 + 4), and then assigns that value to the variable on the left-hand-side.

# %%
# This is a comment. In Python, comments begin with the `#` symbol.
## Ordering Spam, egg, Spam, Spam, bacon and Spam (4 more servings of Spam)
spam_amount += 4

# %% [markdown]
# #### Conditionals
# Note how we indicated which code belongs to the `if`. `"But I don't want ANY spam!"` is only supposed to be printed if `spam_amount` is positive. But the later code (like `print(viking_song)`) should be executed no matter what.

# %%
if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam Spam Spam"
print(viking_song)
# Out:
# But I don't want ANY spam!
# Spam Spam Spam

# %% [markdown]
# The `*` operater can be used to multiply two numbers (`3 * 3` evaluates to 9), but we can also multiply a string by a number, to get a version that's been repeated that many times.

# %%
viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# Spam Spam Spam Spam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We could ask Python how it would describe the type of thing that `spam_amount` is: It's an `int` - short for integer.
# > `type()` is a built-in function we've seen after `print()`. It's very useful to be able to ask Python "what kind of thing is this?"

# %%
type(spam_amount)
# Out:
# int

# %%
type(20.45)
# Out:
# float

# %% [markdown]
# Python can do two kinds of division. "True division" is basically what your calculator does:
# > It always gives us a `float`.

# %%
print(5/2)
print(6/2)
# Out:
# 2.5
# 3.0

# %% [markdown]
# The `//` operator gives us a result that's rounded down to the next integer.

# %%
print(5//2)
print(6//2)
# Out:
# 2
# 3

# %% [markdown]
# #### Order of operations
# The arithmetic we learned in primary school has conventions about the order in which operations are evaluated. Some remember these by a mnemonic such as **PEMDAS - Parentheses, Exponents, Multiplication/Division, Addition/Subtraction.**

# %%
-3 + 4 * 2
# Out:
# 5

# %% [markdown]
# Sometimes the default order of operations isn't what we want:
#
# Parentheses are useful here. You can add them to force Python to evaluate sub-expressions in whatever order you want.

# %%
hat_height_cm = 25
my_height_cm = 190
# How tall am I, in meters, when wearing my hat?
total_height_meters = (hat_height_cm + my_height_cm) / 10
print("Height in meters =", total_height_meters)
# Out:
# Height in meters = 21.5

# %% [markdown]
# #### Builtin functions for working with numbers
# `min` and `max` return the minimum and maximum of their arguments, respectively...

# %%
print(min(1,2,3))
print(max(1,2,3))
# Out:
# 1
# 3

# %% [markdown]
# `abs` returns the absolute value of an argument:

# %%
print(abs(32))
print(abs(-32))
# Out:
# 32
# 32

# %% [markdown]
# In addition to being the names of Python's two main numerical types, `int` and `float` can also be called as functions which convert their arguments to the corresponding type:

# %%
print(float(10))
print(int(3.33))
# They can even be called on strings!
print(int('807') + 1)
# Out:
# 10.0
# 3
# 808
